# %%
import pandas as pd

# %%
df = pd.read_csv('cricketdatacsv.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# 1   91.76    4   7   1   141  23
# 2   55.68    5   4   2   186   5
# 3   54.48    7  11   1   246  11
# 4   56.00   10   5   2   104   1
# ..    ...  ...  ..  ..   ...  ..
# 57  49.16   15  33   4   525  23
# 58  59.67   27  38  11  1165  24
# 59  44.77    7   6   1   119   0
# 60  60.02    6  13   4   241   5
# 61  25.59    1  10   2    53   0
#
# [62 rows x 15 columns]

# %%
df = df.rename(columns = { 'NO':'Not_Outs', 'HS':'Highest_Inns_Score', 'BF' :"Balls_Faced", 'SR':'Batting_Strike_Rate'})

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485
# 3     RG Pollock (SA)  1963-1970   23    41         4  2256
# 4     GA Headley (WI)  1930-1954   22    40         4  2190
# ..                ...        ...  ...   ...       ...   ...
# 57   KD Walters (AUS)  1965-1981   74   125        14  5357
# 58  GC Smith (ICC/SA)  2002-2014  117   205        13  9265
# 59  WH Ponsford (AUS)  1924-1934   29    48         4  2122
# 60    SJ McCabe (AUS)  1930-1938   39    62         5  2748
# 61   DR Jardine (ENG)  1928-1934   22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# 1                 186  62.15        1287                91.76    4   7   1
# 2                269*  61.87        2667                55.68    5   4   2
# 3                 274  60.97       1707+                54.48    7  11   1
# 4                270*  60.83        416+                56.00   10   5   2
# ..                ...    ...         ...                  ...  ...  ..  ..
# 57                250  48.26       8662+                49.16   15  33   4
# 58                277  48.25       15525                59.67   27  38  11
# 59                266  48.22       3118+                44.77    7   6   1
# 60                232  48.21       3217+                60.02    6  13   4
# 61                127  48.00       2110+                25.59    1  10   2
#
#       4s  6s
# 0    626   6
# 1    141  23
# 2    186   5
# 3    246  11
# 4    104   1
# ..   ...  ..
# 57   525  23
# 58  1165  24
# 59   119   0
# 60   241   5
# 61    53   0
#
# [62 rows x 15 columns]

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Mat                    False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Mat  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958   48    81         5  4455
# 14       CL Walcott (WI)  1948-1960   44    74         7  3798
# 54  Hon.FS Jackson (ENG)  1893-1905   20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                 207  58.61         NaN                  0.0   15  19  6
# 14                220  56.68         NaN                  0.0   15  14  1
# 54               144*  48.79         NaN                  0.0    5   6  3
#
#      4s  6s
# 8   258   2
# 14  107  11
# 54   51   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Mat  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 8  ED Weekes (WI)  1948-1958   48    81         5  4455                207
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s
# 8  58.61           0                  0.0   15  19  6  258   2

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Mat, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df['Span'].str.split(pat ='-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat ='-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat ='-').str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485
# 3     RG Pollock (SA)  1963-1970   23    41         4  2256
# 4     GA Headley (WI)  1930-1954   22    40         4  2190
# ..                ...        ...  ...   ...       ...   ...
# 57   KD Walters (AUS)  1965-1981   74   125        14  5357
# 58  GC Smith (ICC/SA)  2002-2014  117   205        13  9265
# 59  WH Ponsford (AUS)  1924-1934   29    48         4  2122
# 60    SJ McCabe (AUS)  1930-1938   39    62         5  2748
# 61   DR Jardine (ENG)  1928-1934   22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# 1                 186  62.15        1287                91.76    4   7   1
# 2                269*  61.87        2667                55.68    5   4   2
# 3                 274  60.97       1707+                54.48    7  11   1
# 4                270*  60.83        416+                56.00   10   5   2
# ..                ...    ...         ...                  ...  ...  ..  ..
# 57                250  48.26       8662+                49.16   15  33   4
# 58                277  48.25       15525                59.67   27  38  11
# 59                266  48.22       3118+                44.77    7   6   1
# 60                232  48.21       3217+                60.02    6  13   4
# 61                127  48.00       2110+                25.59    1  10   2
#
#       4s  6s Rookie_Year Final_Year
# 0    626   6        1928       1948
# 1    141  23        2022       2023
# 2    186   5        2015       2016
# 3    246  11        1963       1970
# 4    104   1        1930       1954
# ..   ...  ..         ...        ...
# 57   525  23        1965       1981
# 58  1165  24        2002       2014
# 59   119   0        1924       1934
# 60   241   5        1930       1938
# 61    53   0        1928       1934
#
# [62 rows x 17 columns]

# %%
df = df.drop(['Span'],axis=1)

# %%
df.head()
# Out:
#              Player  Mat  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)   52    80        10  6996                334  99.94
# 1    HC Brook (ENG)   12    20         1  1181                186  62.15
# 2    AC Voges (AUS)   20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)   23    41         4  2256                274  60.97
# 4   GA Headley (WI)   22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year
# 0       9800+                58.60   29  13  7  626   6        1928       1948
# 1        1287                91.76    4   7  1  141  23        2022       2023
# 2        2667                55.68    5   4  2  186   5        2015       2016
# 3       1707+                54.48    7  11  1  246  11        1963       1970
# 4        416+                56.00   10   5  2  104   1        1930       1954

# %%
df['Player'].str.split(pat ='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 57     [KD Walters , AUS)]
# 58    [GC Smith , ICC/SA)]
# 59    [WH Ponsford , AUS)]
# 60      [SJ McCabe , AUS)]
# 61     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat ='(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat =')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 57       AUS
# 58    ICC/SA
# 59       AUS
# 60       AUS
# 61       ENG
# Name: Country, Length: 62, dtype: object

# %%
df['Player']
# Out:
# 0      DG Bradman (AUS)
# 1        HC Brook (ENG)
# 2        AC Voges (AUS)
# 3       RG Pollock (SA)
# 4       GA Headley (WI)
#             ...
# 57     KD Walters (AUS)
# 58    GC Smith (ICC/SA)
# 59    WH Ponsford (AUS)
# 60      SJ McCabe (AUS)
# 61     DR Jardine (ENG)
# Name: Player, Length: 62, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head
# Out:
# <bound method NDFrame.head of           Player  Mat  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman    52    80        10  6996                334  99.94
# 1      HC Brook    12    20         1  1181                186  62.15
# 2      AC Voges    20    31         7  1485               269*  61.87
# 3    RG Pollock    23    41         4  2256                274  60.97
# 4    GA Headley    22    40         4  2190               270*  60.83
# ..           ...  ...   ...       ...   ...                ...    ...
# 57   KD Walters    74   125        14  5357                250  48.26
# 58     GC Smith   117   205        13  9265                277  48.25
# 59  WH Ponsford    29    48         4  2122                266  48.22
# 60    SJ McCabe    39    62         5  2748                232  48.21
# 61   DR Jardine    22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# 0        9800+                58.60   29  13   7   626   6        1928
# 1         1287                91.76    4   7   1   141  23        2022
# 2         2667                55.68    5   4   2   186   5        2015
# 3        1707+                54.48    7  11   1   246  11        1963
# 4         416+                56.00   10   5   2   104   1        1930
# ..         ...                  ...  ...  ..  ..   ...  ..         ...
# 57       8662+                49.16   15  33   4   525  23        1965
# 58       15525                59.67   27  38  11  1165  24        2002
# 59       3118+                44.77    7   6   1   119   0        1924
# 60       3217+                60.02    6  13   4   241   5        1930
# 61       2110+                25.59    1  10   2    53   0        1928
#
#    Final_Year Country
# 0        1948     AUS
# 1        2023     ENG
# 2        2016     AUS
# 3        1970      SA
# 4        1954      WI
# ..        ...     ...
# 57       1981     AUS
# 58       2014  ICC/SA
# 59       1934     AUS
# 60       1938     AUS
# 61       1934     ENG
#
# [62 rows x 17 columns]>

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat ='*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'] =df['Highest_Inns_Score'].str.split(pat ='*').str[0]

# %%
df["Highest_Inns_Score"]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'].astype('int')
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: Highest_Inns_Score, Length: 62, dtype: int64

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] =df['Balls_Faced'].str.split(pat ='+').str[0]

# %%
df['Balls_Faced']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: Balls_Faced, Length: 62, dtype: object

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df['Balls_Faced'] = df['Balls_Faced'].astype('int')
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/internals/blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:138, in _astype_nansafe(arr, dtype, copy, skipna)
#     134     raise ValueError(msg)
#     136 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     137     # Explicit copy, or required since NumPy can't view from / to object.
# --> 138     return arr.astype(dtype, copy=True)
#     140 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %%
df['Balls_Faced']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: Balls_Faced, Length: 62, dtype: object

# %%
df = df.astype({'Rookie_Year':'int','Final_Year' :'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of           Player  Mat  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman    52    80        10  6996                 334  99.94
# 1      HC Brook    12    20         1  1181                 186  62.15
# 2      AC Voges    20    31         7  1485                 269  61.87
# 3    RG Pollock    23    41         4  2256                 274  60.97
# 4    GA Headley    22    40         4  2190                 270  60.83
# ..           ...  ...   ...       ...   ...                 ...    ...
# 57   KD Walters    74   125        14  5357                 250  48.26
# 58     GC Smith   117   205        13  9265                 277  48.25
# 59  WH Ponsford    29    48         4  2122                 266  48.22
# 60    SJ McCabe    39    62         5  2748                 232  48.21
# 61   DR Jardine    22    33         6  1296                 127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rookie_Year  \
# 0         9800                58.60   29  13   7   626   6         1928
# 1         1287                91.76    4   7   1   141  23         2022
# 2         2667                55.68    5   4   2   186   5         2015
# 3         1707                54.48    7  11   1   246  11         1963
# 4          416                56.00   10   5   2   104   1         1930
# ..         ...                  ...  ...  ..  ..   ...  ..          ...
# 57        8662                49.16   15  33   4   525  23         1965
# 58       15525                59.67   27  38  11  1165  24         2002
# 59        3118                44.77    7   6   1   119   0         1924
# 60        3217                60.02    6  13   4   241   5         1930
# 61        2110                25.59    1  10   2    53   0         1928
#
#     Final_Year Country
# 0         1948     AUS
# 1         2023     ENG
# 2         2016     AUS
# 3         1970      SA
# 4         1954      WI
# ..         ...     ...
# 57        1981     AUS
# 58        2014  ICC/SA
# 59        1934     AUS
# 60        1938     AUS
# 61        1934     ENG
#
# [62 rows x 17 columns]>

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].astype('float')

# %%
df['Batting_Strike_Rate']
# Out:
# 0     58.60
# 1     91.76
# 2     55.68
# 3     54.48
# 4     56.00
#       ...
# 57    49.16
# 58    59.67
# 59    44.77
# 60    60.02
# 61    25.59
# Name: Batting_Strike_Rate, Length: 62, dtype: float64

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: Highest_Inns_Score, Length: 62, dtype: int64

# %%
df['Highest_Inns_Score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: Highest_Inns_Score, Length: 62, dtype: int64

# %%
df = df.drop(['Highest_Inns_Score'], axis=1)

# %%
df.head()
# Out:
#         Player  Mat  Inns  Not_Outs  Runs    Ave Balls_Faced  \
# 0  DG Bradman    52    80        10  6996  99.94        9800
# 1    HC Brook    12    20         1  1181  62.15        1287
# 2    AC Voges    20    31         7  1485  61.87        2667
# 3  RG Pollock    23    41         4  2256  60.97        1707
# 4  GA Headley    22    40         4  2190  60.83         416
#
#    Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  Final_Year Country
# 0                58.60   29  13  7  626   6         1928        1948     AUS
# 1                91.76    4   7  1  141  23         2022        2023     ENG
# 2                55.68    5   4  2  186   5         2015        2016     AUS
# 3                54.48    7  11  1  246  11         1963        1970      SA
# 4                56.00   10   5  2  104   1         1930        1954      WI

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#         Player  Mat  Inns  Not_Outs  Runs    Ave Balls_Faced  \
# 0  DG Bradman    52    80        10  6996  99.94        9800
# 1    HC Brook    12    20         1  1181  62.15        1287
# 2    AC Voges    20    31         7  1485  61.87        2667
# 3  RG Pollock    23    41         4  2256  60.97        1707
# 4  GA Headley    22    40         4  2190  60.83         416
#
#    Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  Final_Year Country
# 0                58.60   29  13  7  626   6         1928        1948     AUS
# 1                91.76    4   7  1  141  23         2022        2023     ENG
# 2                55.68    5   4  2  186   5         2015        2016     AUS
# 3                54.48    7  11  1  246  11         1963        1970      SA
# 4                56.00   10   5  2  104   1         1930        1954      WI

# %%
df.isnull().any()
# Out:
# Player                 False
# Mat                    False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df["Balls_Faced"]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: Balls_Faced, Length: 62, dtype: object

# %%
df["Balls_Faced"].fillna(0, inplace=True)

# %%
df["Balls_Faced"]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: Balls_Faced, Length: 62, dtype: object

# %%
df.isnull().any()
# Out:
# Player                 False
# Mat                    False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
file_path ="cleaned_cricket_data.csv"

# %%
df.to_csv(file_path, index=False)
